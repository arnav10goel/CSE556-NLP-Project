# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4]
train_loss = [0.4819, 0.2816, 0.1599, 0.1347]
val_loss = [0.3295, 0.2586, 0.1586, 0.1312]

plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')


plt.title('Training and Validation Loss Progression\nfor Sentiment Analysis Fine-Tuning (Hindi)', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12, fontweight='bold')
plt.ylabel('Loss', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4]
train_loss = [0.6445, 0.5344, 0.4543, 0.3639]
val_loss = [0.6727, 0.4997, 0.434, 0.3498]

plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')

plt.title('Training and Validation Loss Progression\nfor Hate Speech Detection Fine-Tuning (Hindi)', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12, fontweight='bold')
plt.ylabel('Loss', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4, 5, 6]
train_loss = [0.7247, 0.3149, 0.2069, 0.1450, 0.1158, 0.1023]
val_loss = [0.3596, 0.2818, 0.2030, 0.14560, 0.1240, 0.1263]

plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')

plt.title('Training and Validation Loss Progression\nfor Named Entity Recognition Fine-Tuning (Hindi)', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12, fontweight='bold')
plt.ylabel('Loss', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4, 5, 6]
train_loss = [0.7164, 0.3444, 0.2402, 0.1783, 0.1339, 0.1098]
val_loss = [0.3993, 0.3011, 0.2012, 0.1874, 0.1632, 0.1447]

plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')

plt.title('Training and Validation Loss Progression\nfor NER Fine-Tuning (Tamil)', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12, fontweight='bold')
plt.ylabel('Loss', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4]
train_loss = [0.6487, 0.5450, 0.4348, 0.3031]
val_loss = [0.7051, 0.4993, 0.3967, 0.2882]

plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')

plt.title('Training and Validation Loss Progression\nfor Hate Detection Fine-Tuning (Tamil)', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12, fontweight='bold')
plt.ylabel('Loss', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3, 4]
train_loss = [0.4840, 0.2618, 0.1480, 0.1075]
val_loss = [0.5717, 0.2963, 0.1325, 0.0993]

plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')

plt.title('Training and Validation Loss Progression\nfor Sentiment Analysis Fine-Tuning (Tamil)', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12, fontweight='bold')
plt.ylabel('Loss', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs)
plt.show()
