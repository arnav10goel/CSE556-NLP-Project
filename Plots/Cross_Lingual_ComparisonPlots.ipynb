# %%
import matplotlib.pyplot as plt

# Sample accuracy values for illustration
training_sizes = [200, 500, 1000]
marathi_accuracy = [0.756, 0.762, 0.788]  # Accuracy of Marathi after fine-tuning on Hindi
bengali_accuracy = [0.602, 0.782, 0.852]  # Accuracy of Bengali after fine-tuning on Hindi
tamil_accuracy = [0.570, 0.788, 0.807]  # Accuracy of Tamil after fine-tuning on Hindi
telugu_accuracy = [0.698, 0.730, 0.782]  # Accuracy of Telugu after fine-tuning on Hindi

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(training_sizes, marathi_accuracy, marker='o', label='Marathi', linewidth=2)
plt.plot(training_sizes, bengali_accuracy, marker='o', label='Bengali', linewidth=2)
plt.plot(training_sizes, tamil_accuracy, marker='o', label='Tamil', linewidth=2)
plt.plot(training_sizes, telugu_accuracy, marker='o', label='Telugu', linewidth=2)

plt.xlabel('Training Data Size', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Effect of Fine-Tuning on Hindi on Other Languages For Sentiment Analysis', fontsize=16, weight='bold')
plt.xticks(training_sizes, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.legend(fontsize=14, prop={'size': 14, 'weight': 'bold'})
plt.grid(True)

plt.show()

# %%
# Accuracy data for each language and training size
training_sizes = [200, 500, 1000]

# Accuracy for Hindi
hindi_accuracy = [0.7949, 0.7564, 0.8590]
# Accuracy for Marathi
marathi_accuracy = [0.7692, 0.6603, 0.7372]
# Accuracy for Bengali
bengali_accuracy = [0.8205, 0.6731, 0.8077]
# Accuracy for Telugu
telugu_accuracy = [0.7308, 0.6154, 0.7756]


# Plotting
plt.figure(figsize=(10, 6))

plt.plot(training_sizes, hindi_accuracy, marker='o', label='Hindi', linewidth=2)
plt.plot(training_sizes, marathi_accuracy, marker='o', label='Marathi', linewidth=2)
plt.plot(training_sizes, bengali_accuracy, marker='o', label='Bengali', linewidth=2)
plt.plot(training_sizes, telugu_accuracy, marker='o', label='Telugu', linewidth=2)

plt.xlabel('Training Data Size', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Effect of Fine-Tuning on Tamil on Other Languages For Sentiment Analysis', fontsize=16, weight='bold')
plt.xticks(training_sizes, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.legend(fontsize=14, prop={'size': 14, 'weight': 'bold'})
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Training sizes
training_sizes = [1000, 2000, 4000]

# Accuracy for Marathi
marathi_accuracy = [0.717, 0.646, 0.736]

# Accuracy for Bengali
bengali_accuracy = [0.653, 0.621, 0.658]

# Accuracy for Tamil
tamil_accuracy = [0.596, 0.457, 0.600]

# Accuracy for Telugu
telugu_accuracy = [0.507, 0.574, 0.549]


# Plotting
plt.figure(figsize=(10, 6))

plt.plot(training_sizes, marathi_accuracy, marker='o', label='Marathi', linewidth=2)
plt.plot(training_sizes, bengali_accuracy, marker='o', label='Bengali', linewidth=2)
plt.plot(training_sizes, tamil_accuracy, marker='o', label='Tamil', linewidth=2)
plt.plot(training_sizes, telugu_accuracy, marker='o', label='Telugu', linewidth=2)

plt.xlabel('Training Data Size', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Effect of Fine-Tuning on Hindi on Other Languages For Hate Speech', fontsize=16, weight='bold')
plt.xticks(training_sizes, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.legend(fontsize=14, prop={'size': 14, 'weight': 'bold'})
plt.grid(True)

plt.show()

# %%
# Training sizes
training_sizes = [1000, 2000, 4000]

# Accuracy for Hindi
hindi_accuracy = [0.521, 0.530, 0.536]

# Accuracy for Marathi
marathi_accuracy = [0.570, 0.621, 0.592]

# Accuracy for Bengali
bengali_accuracy = [0.599, 0.612, 0.544]


# Accuracy for Telugu
telugu_accuracy = [0.529, 0.565, 0.557]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(training_sizes, hindi_accuracy, marker='o', label='Hindi', linewidth=2)
plt.plot(training_sizes, marathi_accuracy, marker='o', label='Marathi', linewidth=2)
plt.plot(training_sizes, bengali_accuracy, marker='o', label='Bengali', linewidth=2)
plt.plot(training_sizes, telugu_accuracy, marker='o', label='Telugu', linewidth=2)

plt.xlabel('Training Data Size', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Effect of Fine-Tuning on Tamil on Other Languages For Hate Speech', fontsize=16, weight='bold')
plt.xticks(training_sizes, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.legend(fontsize=14, prop={'size': 14, 'weight': 'bold'})
plt.grid(True)

plt.show()

# %%
# Training sizes
training_sizes = [1000, 2000, 4000]

# Accuracy for Hindi
hindi_accuracy = [0.8826, 0.9164, 0.9334]

# Accuracy for Marathi
marathi_accuracy = [0.8271, 0.8391, 0.8280]

# Accuracy for Bengali
bengali_accuracy = [0.7546, 0.7669, 0.7939]

# Accuracy for Tamil
tamil_accuracy = [0.7945, 0.7998, 0.7991]

# Accuracy for Telugu
telugu_accuracy = [0.8195, 0.8231, 0.8163]


# Plotting
plt.figure(figsize=(10, 6))

plt.plot(training_sizes, marathi_accuracy, marker='o', label='Marathi', linewidth=2)
plt.plot(training_sizes, bengali_accuracy, marker='o', label='Bengali', linewidth=2)
plt.plot(training_sizes, tamil_accuracy, marker='o', label='Tamil', linewidth=2)
plt.plot(training_sizes, telugu_accuracy, marker='o', label='Telugu', linewidth=2)

plt.xlabel('Training Data Size', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Effect of Fine-Tuning on Hindi on Other Languages For NER', fontsize=16, weight='bold')
plt.xticks(training_sizes, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.legend(fontsize=14, prop={'size': 14, 'weight': 'bold'})
plt.grid(True)

plt.show()

# %%
# Training sizes
training_sizes = [1000, 2000, 4000]

# Accuracy for Hindi
hindi_accuracy = [0.7833, 0.8035, 0.8027]

# Accuracy for Marathi
marathi_accuracy = [0.8272, 0.8250, 0.8397]

# Accuracy for Bengali
bengali_accuracy = [0.7085, 0.7791, 0.7617]

# Accuracy for Tamil
tamil_accuracy = [0.8792, 0.8986, 0.9137]

# Accuracy for Telugu
telugu_accuracy = [0.8325, 0.8602, 0.8408]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(training_sizes, hindi_accuracy, marker='o', label='Hindi', linewidth=2)
plt.plot(training_sizes, marathi_accuracy, marker='o', label='Marathi', linewidth=2)
plt.plot(training_sizes, bengali_accuracy, marker='o', label='Bengali', linewidth=2)
plt.plot(training_sizes, telugu_accuracy, marker='o', label='Telugu', linewidth=2)

plt.xlabel('Training Data Size', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Effect of Fine-Tuning on Tamil on Other Languages For NER', fontsize=16, weight='bold')
plt.xticks(training_sizes, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.legend(fontsize=14, prop={'size': 14, 'weight': 'bold'})
plt.grid(True)

plt.show()
